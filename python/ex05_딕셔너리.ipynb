# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
chsun = {"이름":"김창선","나이":"31","번호":"01040442901"}
chsun
# Out:
# {'이름': '김창선', '나이': '31', '번호': '01040442901'}

# %%
# 데이터 추출
# 딕셔너리명[key]
chsun["이름"]
# Out:
# '김창선'

# %%
# 데이터 추가
chsun["취미"] = "코딩"
chsun
# Out:
# {'이름': '김창선', '나이': '31', '번호': '01040442901', '취미': '코딩'}

# %%
# 데이터 확인
# key값 확인
chsun.keys()
# Out:
# dict_keys(['이름', '나이', '번호', '취미'])

# %%
# value값만 확인하기
chsun.values()
# Out:
# dict_values(['김창선', '31', '01040442901', '코딩'])

# %%
chsun["취미"] = ["코딩", "공부", "여행"]
chsun
# Out:
# {'이름': '김창선', '나이': '31', '번호': '01040442901', '취미': ['코딩', '공부', '여행']}

# %%
chsun["취미"]
# Out:
# ['코딩', '공부', '여행']

# %%
chsun["취미"][2]
# Out:
# '여행'
